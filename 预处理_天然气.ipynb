# %% [markdown]
# ## 1、数据导入

# %%
import pandas as pd

# %%
df_csv = pd.read_csv('天然气期货历史数据.csv')
df_csv.head()
# Out:
#           日期     收盘     开盘      高      低     涨跌幅       交易量
# 0   2024/5/1  1.932  1.954  1.970  1.913  -2.96%  13592.0%
# 1  2024/4/30  1.991  2.050  2.092  1.951  -1.92%  15037.0%
# 2  2024/4/29  2.030  1.923  2.056  1.916  25.77%  15886.0%
# 3  2024/4/26  1.614  1.622  1.628  1.482  -1.47%    493.0%
# 4  2024/4/25  1.638  1.644  1.675  1.583  -0.91%   7548.0%

# %% [markdown]
# ## 2、数据信息查看

# %%
data = df_csv

# %%
# 查看数据规模（维度）
data.shape
# Out:
# (575, 7)

# %%
# 查看各变量的数据类型
data.dtypes
# Out:
# 日期      object
# 收盘     float64
# 开盘     float64
# 高      float64
# 低      float64
# 涨跌幅     object
# 交易量     object
# dtype: object

# %%
# 查看数据整体信息
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日期      575 non-null    object
#  1   收盘      575 non-null    float64
#  2   开盘      575 non-null    float64
#  3   高       575 non-null    float64
#  4   低       575 non-null    float64
#  5   涨跌幅     575 non-null    object
#  6   交易量     543 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 31.6+ KB

# %%
# 查看数据描述
data.describe()
# Out:
#                收盘          开盘           高           低
# count  575.000000  575.000000  575.000000  575.000000
# mean     4.230026    4.245157    4.381854    4.094191
# std      2.344839    2.349427    2.438902    2.255242
# min      1.551000    1.527000    1.565000    1.481000
# 25%      2.464000    2.455500    2.558000    2.388000
# 50%      2.899000    2.891000    2.960000    2.820000
# 75%      6.311000    6.337000    6.596000    6.060000
# max      9.647000    9.780000    9.987000    9.200000

# %%
# 列名
data.columns
# Out:
# Index(['日期', '收盘', '开盘', '高', '低', '涨跌幅', '交易量'], dtype='object')

# %%
# 查看前五行
data.head()
# Out:
#           日期     收盘     开盘      高      低     涨跌幅       交易量
# 0   2024/5/1  1.932  1.954  1.970  1.913  -2.96%  13592.0%
# 1  2024/4/30  1.991  2.050  2.092  1.951  -1.92%  15037.0%
# 2  2024/4/29  2.030  1.923  2.056  1.916  25.77%  15886.0%
# 3  2024/4/26  1.614  1.622  1.628  1.482  -1.47%    493.0%
# 4  2024/4/25  1.638  1.644  1.675  1.583  -0.91%   7548.0%

# %%
# 查看后五行
data.tail()
# Out:
#            日期     收盘     开盘      高      低     涨跌幅     交易量
# 570  2022/3/7  4.833  5.041  5.184  4.781  -3.65%  130.86
# 571  2022/3/4  5.016  4.750  5.045  4.728   6.23%  125.39
# 572  2022/3/3  4.722  4.795  4.936  4.628  -0.84%  137.15
# 573  2022/3/2  4.762  4.600  4.911  4.600   4.13%  141.69
# 574  2022/3/1  4.573  4.408  4.627  4.340   3.88%  112.55

# %% [markdown]
# ## 3、数据清洗以及预处理

# %% [markdown]
# ### 查找空值

# %%
# 查找空值 判断各变量中是否存在缺失值
data.isnull().any(axis = 0)
# Out:
# 日期     False
# 收盘     False
# 开盘     False
# 高      False
# 低      False
# 涨跌幅    False
# 交易量     True
# dtype: bool

# %%
# 查找空值 判断数据行中是否存在缺失值
data.isnull().any(axis = 1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 570    False
# 571    False
# 572    False
# 573    False
# 574    False
# Length: 575, dtype: bool

# %%
# 定位缺失值所在的行
data.loc[data.isnull().any(axis = 1)]
# Out:
#              日期     收盘     开盘      高      低     涨跌幅  交易量
# 51    2024/2/19  1.558  1.552  1.583  1.540   0.45%  NaN
# 52    2024/2/18  1.551  1.527  1.565  1.527  -7.68%  NaN
# 77    2024/1/15  3.066  3.112  3.188  3.055  -1.45%  NaN
# 78    2024/1/14  3.111  3.104  3.137  3.077  -6.10%  NaN
# 88     2024/1/1  2.667  2.614  2.670  2.614   6.09%  NaN
# 93   2023/12/25  2.418  2.425  2.442  2.415  -7.36%  NaN
# 115  2023/11/23  2.930  2.880  2.938  2.861   1.14%  NaN
# 173    2023/9/4  2.647  2.671  2.708  2.642  -0.90%  NaN
# 174    2023/9/3  2.671  2.692  2.694  2.652  -3.40%  NaN
# 218    2023/7/4  2.751  2.689  2.758  2.662   1.55%  NaN
# 229   2023/6/19  2.643  2.604  2.683  2.569   1.58%  NaN
# 230   2023/6/18  2.602  2.613  2.623  2.598  -1.14%  NaN
# 245   2023/5/29  2.349  2.434  2.447  2.338  -3.53%  NaN
# 246   2023/5/28  2.435  2.418  2.441  2.417  11.65%  NaN
# 315   2023/2/20  2.324  2.304  2.373  2.271   0.82%  NaN
# 316   2023/2/19  2.305  2.303  2.306  2.284  -2.00%  NaN
# 341   2023/1/16  3.675  3.601  3.696  3.524   2.05%  NaN
# 342   2023/1/15  3.601  3.591  3.615  3.554   5.32%  NaN
# 352    2023/1/2  4.143  4.222  4.222  4.072  -7.42%  NaN
# 357  2022/12/26  5.144  5.179  5.188  5.037   3.29%  NaN
# 379  2022/11/24  7.177  7.307  7.404  7.100  -1.79%  NaN
# 434    2022/9/8  7.954  7.883  8.057  7.774   1.43%  NaN
# 437    2022/9/5  8.714  8.980  8.995  8.710  -2.95%  NaN
# 438    2022/9/4  8.979  9.086  9.096  8.946   2.20%  NaN
# 479    2022/7/8  6.034  6.188  6.305  6.012  -4.18%  NaN
# 483    2022/7/4  5.853  5.712  5.905  5.606   2.52%  NaN
# 484    2022/7/3  5.709  5.701  5.734  5.678  -0.37%  NaN
# 494   2022/6/20  6.713  6.706  6.840  6.635   0.16%  NaN
# 495   2022/6/19  6.702  6.752  6.758  6.659  -3.49%  NaN
# 510   2022/5/30  8.686  8.819  8.908  8.598  -1.46%  NaN
# 511   2022/5/29  8.815  8.829  8.841  8.701   1.01%  NaN
# 534   2022/4/27  7.339  7.009  7.524  6.956   7.14%  NaN

# %%
# 各变量中缺失值的数量
data.isnull().sum(axis = 0)
# Out:
# 日期      0
# 收盘      0
# 开盘      0
# 高       0
# 低       0
# 涨跌幅     0
# 交易量    32
# dtype: int64

# %% [markdown]
# ### 处理空值

# %%
# 直接删除空值数据所在行（不采用
# data3 = data.dropna()
# data3

# %%
# 定义缺失值为0
data_null_0 = data.fillna(0,inplace = False)
data_null_0
# Out:
#             日期     收盘     开盘      高      低     涨跌幅       交易量
# 0     2024/5/1  1.932  1.954  1.970  1.913  -2.96%  13592.0%
# 1    2024/4/30  1.991  2.050  2.092  1.951  -1.92%  15037.0%
# 2    2024/4/29  2.030  1.923  2.056  1.916  25.77%  15886.0%
# 3    2024/4/26  1.614  1.622  1.628  1.482  -1.47%    493.0%
# 4    2024/4/25  1.638  1.644  1.675  1.583  -0.91%   7548.0%
# ..         ...    ...    ...    ...    ...     ...       ...
# 570   2022/3/7  4.833  5.041  5.184  4.781  -3.65%    130.86
# 571   2022/3/4  5.016  4.750  5.045  4.728   6.23%    125.39
# 572   2022/3/3  4.722  4.795  4.936  4.628  -0.84%    137.15
# 573   2022/3/2  4.762  4.600  4.911  4.600   4.13%    141.69
# 574   2022/3/1  4.573  4.408  4.627  4.340   3.88%    112.55
#
# [575 rows x 7 columns]

# %%
# 对缺失值进行填充（用中位数或者平均数.....）
# 采用平均值
# 定义一个函数，用于将带有"k"的值转换为浮点数
# def k_to_float(value):
#     if isinstance(value, str) and value.endswith("K"):
#         return float(value[:-1]) * 1000
#     else:
#         return float(value)

# # 对包含"k"单位的列应用函数
# df_csv['交易量'] = df_csv['交易量'].apply(k_to_float)
# # 填充平均值
# data_null_value = data.fillna(value = {'交易量':data['交易量'].mean()},inplace = False)
# data_null_value

# %%
# 源数据未改变
data.isnull().sum(axis = 0)
# Out:
# 日期      0
# 收盘      0
# 开盘      0
# 高       0
# 低       0
# 涨跌幅     0
# 交易量    32
# dtype: int64

# %%
# 新数据已无空值
data_null_0.isnull().sum(axis = 0)
# Out:
# 日期     0
# 收盘     0
# 开盘     0
# 高      0
# 低      0
# 涨跌幅    0
# 交易量    0
# dtype: int64

# %%
# 开盘天然气最高的情况
max_row_index = df_csv['开盘'].idxmax()
max_row = df_csv.iloc[max_row_index]
max_row
# Out:
# 日期     2022/8/23
# 收盘         9.155
# 开盘          9.78
# 高          9.987
# 低          9.021
# 涨跌幅       -5.10%
# 交易量        86.53
# Name: 447, dtype: object

# %%
# 收盘天然气最高的情况
max_row_index = df_csv['收盘'].idxmax()
max_row = df_csv.iloc[max_row_index]
max_row
# Out:
# 日期     2022/8/22
# 收盘         9.647
# 开盘         9.159
# 高           9.95
# 低          9.143
# 涨跌幅        3.33%
# 交易量        60.48
# Name: 448, dtype: object

# %%
# 开盘天然气最低的情况
min_row_index = df_csv['开盘'].idxmin()
min_row = df_csv.iloc[min_row_index]
min_row
# Out:
# 日期     2024/2/18
# 收盘         1.551
# 开盘         1.527
# 高          1.565
# 低          1.527
# 涨跌幅       -7.68%
# 交易量          NaN
# Name: 52, dtype: object

# %%
# 收盘天然气最低的情况
min_row_index = df_csv['收盘'].idxmin()
min_row = df_csv.iloc[min_row_index]
min_row
# Out:
# 日期     2024/2/18
# 收盘         1.551
# 开盘         1.527
# 高          1.565
# 低          1.527
# 涨跌幅       -7.68%
# 交易量          NaN
# Name: 52, dtype: object

# %%
# 导出新csv文件
data_null_0.to_csv('天然气(清洗).csv',index=False)
